# %%
# aivietnam.ai - one-max

# Chương trình cài đặt với mục đích dễ hiểu
# Nhiều chỗ có thể cải tiến về mặt computation và memory

import random

n = 20                # size of individual (chromosome)
m = 100                # size of population
n_generations = 40    # number of generations
# crossover_rate
# mutation_rate

# để vẽ biểu đồ quá trình tối ưu
fitnesses = []

def generate_random_value(): # ...
    return random.randint(0, 1)

def compute_fitness(individual): # ...
    return sum(gen for gen in individual)

def create_individual():
    return [generate_random_value() for _ in range(n)]

def crossover(individual1, individual2, crossover_rate = 0.9):
    individual1_new = individual1.copy()
    individual2_new = individual2.copy()
    
    for i in range(n):
        if random.random() < crossover_rate:
            individual1_new[i] = individual2[i]
            individual2_new[i] = individual1[i]            
    
    return individual1_new, individual2_new

def mutate(individual, mutation_rate = 0.05):
    individual_m = individual.copy()
    
    for i in range(n):
        if random.random() < mutation_rate:
            individual_m[i] = generate_random_value()
        
    return individual_m

# population is sorted according to fitness
def selection(sorted_old_population):    
    index1 = random.randint(0, m-1)    
    while True:
        index2 = random.randint(0, m-1)    
        if (index2 != index1):
            break
            
    individual_s = sorted_old_population[index1]
    if index2 > index1:
        individual_s = sorted_old_population[index2]
    
    return individual_s 






def create_new_population(old_population, gen=1):
    sorted_population = sorted(old_population, key=compute_fitness)
        
    if gen%1 == 0:
        fitnesses.append(compute_fitness(sorted_population[m-1]))
        print("BEST:", compute_fitness(sorted_population[m-1]))      
    
    new_population = []
    while len(new_population) < m:
        # selection
        individual_s1 = selection(sorted_population)
        individual_s2 = selection(sorted_population) # duplication
        
        # crossover
        individual_c1, individual_c2 = crossover(individual_s1, individual_s2)
        
        # mutation
        individual_m1 = mutate(individual_c1)
        individual_m2 = mutate(individual_c2)
        
        new_population.append(individual_m1)
        new_population.append(individual_m2) 
    
    return new_population



# step 1
population = [create_individual() for _ in range(m)]

# loops
for i in range(n_generations):
    population = create_new_population(population, i)
# Out:
# BEST: 14
# BEST: 15
# BEST: 16
# BEST: 16
# BEST: 16
# BEST: 17
# BEST: 17
# BEST: 17
# BEST: 18
# BEST: 19
# BEST: 18
# BEST: 18
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 20
# BEST: 20
# BEST: 20
# BEST: 20
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 18
# BEST: 18
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 19
# BEST: 20
# BEST: 19
# BEST: 19
# BEST: 20
# BEST: 20

# %%
import matplotlib.pyplot as plt

plt.plot(fitnesses)
plt.xlabel('Generations')
plt.ylabel('Fitness')
plt.show()

# %%
# aivietnam.ai - one-max

# Chương trình cài đặt với mục đích dễ hiểu
# Nhiều chỗ có thể cải tiến về mặt computation và memory

import random

n = 50                # size of individual (chromosome)
m = 100               # size of population
n_generations = 40    # number of generations

# để vẽ biểu đồ quá trình tối ưu
fitnesses = []

def generate_random_value():
    return random.randint(0, 1)

def compute_fitness(individual):
    return sum(gen for gen in individual)

def create_individual():
    return [generate_random_value() for _ in range(n)]

def crossover(individual1, individual2, crossover_rate = 0.9):
    individual1_new = individual1.copy()
    individual2_new = individual2.copy()
    
    for i in range(n):
        if random.random() < crossover_rate:
            individual1_new[i] = individual2[i]
            individual2_new[i] = individual1[i]            
    
    return individual1_new, individual2_new

def mutate(individual, mutation_rate = 0.05):
    individual_m = individual.copy()
    
    for i in range(n):
        if random.random() < mutation_rate:
            individual_m[i] = generate_random_value()
        
    return individual_m

def selection(sorted_old_population):    
    index1 = random.randint(0, m-1)    
    while True:
        index2 = random.randint(0, m-1)    
        if (index2 != index1):
            break
            
    individual_s = sorted_old_population[index1]
    if index2 > index1:
        individual_s = sorted_old_population[index2]
    
    return individual_s 

def create_new_population(old_population, elitism=2, gen=1):
    sorted_population = sorted(old_population, key=compute_fitness)
        
    if gen%1 == 0:
        fitnesses.append(compute_fitness(sorted_population[m-1]))
        print("BEST:", compute_fitness(sorted_population[m-1]))      
    
    new_population = []
    while len(new_population) < m-elitism:
        # selection
        individual_s1 = selection(sorted_population)
        individual_s2 = selection(sorted_population) # duplication
        
        # crossover
        individual_c1, individual_c2 = crossover(individual_s1, individual_s2)
        
        # mutation
        individual_m1 = mutate(individual_c1)
        individual_m2 = mutate(individual_c2)
        
        new_population.append(individual_m1)
        new_population.append(individual_m2)            
    
    for ind in sorted_population[m-elitism:]:
        new_population.append(ind.copy())
    
    return new_population

population = [create_individual() for _ in range(m)]
for i in range(n_generations):
    population = create_new_population(population, 2, i)
# Out:
# BEST: 36
# BEST: 36
# BEST: 36
# BEST: 36
# BEST: 36
# BEST: 37
# BEST: 38
# BEST: 39
# BEST: 39
# BEST: 41
# BEST: 41
# BEST: 42
# BEST: 43
# BEST: 43
# BEST: 44
# BEST: 44
# BEST: 45
# BEST: 46
# BEST: 46
# BEST: 46
# BEST: 48
# BEST: 48
# BEST: 48
# BEST: 48
# BEST: 48
# BEST: 48
# BEST: 48
# BEST: 49
# BEST: 49
# BEST: 49
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50
# BEST: 50

# %%
import matplotlib.pyplot as plt

plt.plot(fitnesses)
plt.xlabel('Generations')
plt.ylabel('Fitness')
plt.show()

# %%
# aivietnam.ai - sphere

# Chương trình cài đặt với mục đích dễ hiểu
# Nhiều chỗ có thể cải tiến về mặt computation và memory

import random

n = 6                # size of individual (chromosome)
m = 800               # size of population
n_generations = 600   # number of generations

# để vẽ biểu đồ quá trình tối ưu
fitnesses = []

def generate_random_value():
    return (random.random() - 0.5) * 40.0

def compute_fitness(individual):
    return 1.0 / (sum(x*x for x in individual) + 1.0)

def create_individual():
    return [generate_random_value() for _ in range(n)]

def crossover(individual1, individual2, crossover_rate = 0.9):
    individual1_new = individual1.copy()
    individual2_new = individual2.copy()
    
    for i in range(n):
        if random.random() < crossover_rate:
            individual1_new[i] = individual2[i]
            individual2_new[i] = individual1[i]            
    
    return individual1_new, individual2_new

def mutate(individual, mutation_rate = 0.05):
    individual_m = individual.copy()
    
    for i in range(n):
        if random.random() < mutation_rate:
            individual_m[i] = generate_random_value()
        
    return individual_m

def selection(sorted_old_population):    
    index1 = random.randint(0, m-1)    
    while True:
        index2 = random.randint(0, m-1)    
        if (index2 != index1):
            break
            
    individual_s = sorted_old_population[index1]
    if index2 > index1:
        individual_s = sorted_old_population[index2]
    
    return individual_s 

def create_new_population(old_population, elitism=2, gen=1):
    sorted_population = sorted(old_population, key=compute_fitness)
        
    if gen%100 == 0:
        fitnesses.append(compute_fitness(sorted_population[m-1]))
        print("BEST:", compute_fitness(sorted_population[m-1]))      
    
    new_population = []
    while len(new_population) < m-elitism:
        # selection
        individual_s1 = selection(sorted_population)
        individual_s2 = selection(sorted_population) # duplication
        
        # crossover
        individual_c1, individual_c2 = crossover(individual_s1, individual_s2)
        
        # mutation
        individual_m1 = mutate(individual_c1)
        individual_m2 = mutate(individual_c2)
        
        new_population.append(individual_m1)
        new_population.append(individual_m2)            
    
    for ind in sorted_population[m-elitism:]:
        new_population.append(ind.copy())
    
    return new_population

population = [create_individual() for _ in range(m)]
for i in range(n_generations):
    population = create_new_population(population, 2, i)
# Out:
# BEST: 0.020135072474924767
# BEST: 0.9975114963067077
# BEST: 0.9998656093574209
# BEST: 0.9998670448881519
# BEST: 0.9998755923745847
# BEST: 0.9999570297722473

# %%
sorted_population = sorted(population, key=compute_fitness)
print(sorted_population[-1])
# Out:
# [-0.00046276242093856723, 0.0019948576115202954, -0.00018405418109601612, -0.002969062464228678, -4.014637728921855e-06, -0.0029336093990561807]

# %%
# aivietnam.ai - one-max

# Chương trình cài đặt với mục đích dễ hiểu
# Nhiều chỗ có thể cải tiến về mặt computation và memory

import random

n = 20                # size of individual (chromosome)
m = 10                # size of population
n_generations = 40    # number of generations

# để vẽ biểu đồ quá trình tối ưu
fitnesses = []

def generate_random_value():
    return random.randint(0, 1)

def compute_fitness(individual):
    return 1.0 / (sum(gen*gen for gen in individual) + 1.0)

def create_individual():
    return [generate_random_value() for _ in range(n)]

def crossover(individual1, individual2, crossover_rate = 0.9):
    individual1_new = individual1.copy()
    individual2_new = individual2.copy()
    
    for i in range(n):
        if random.random() < crossover_rate:
            individual1_new[i] = individual2[i]
            individual2_new[i] = individual1[i]            
    
    return individual1_new, individual2_new

def mutate(individual, mutation_rate = 0.05):
    individual_m = individual.copy()
    
    for i in range(n):
        if random.random() < mutation_rate:
            individual_m[i] = generate_random_value()
        
    return individual_m

def selection(sorted_old_population):    
    index1 = random.randint(0, m-1)    
    while True:
        index2 = random.randint(0, m-1)    
        if (index2 != index1):
            break
            
    individual_s = sorted_old_population[index1]
    if index2 > index1:
        individual_s = sorted_old_population[index2]
    
    return individual_s 

def create_new_population(old_population, elitism=2, gen=1):
    sorted_population = sorted(old_population, key=compute_fitness)
        
    if gen%1 == 0:
        fitnesses.append(compute_fitness(sorted_population[m-1]))
        print("BEST:", compute_fitness(sorted_population[m-1]))      
    
    new_population = []
    while len(new_population) < m-elitism:
        # selection
        individual_s1 = selection(sorted_population)
        individual_s2 = selection(sorted_population) # duplication
        
        # crossover
        individual_c1, individual_c2 = crossover(individual_s1, individual_s2)
        
        # mutation
        individual_m1 = mutate(individual_c1)
        individual_m2 = mutate(individual_c2)
        
        new_population.append(individual_m1)
        new_population.append(individual_m2)            
    
    for ind in sorted_population[m-elitism:]:
        new_population.append(ind.copy())
    
    return new_population

population = [create_individual() for _ in range(m)]
for i in range(n_generations):
    population = create_new_population(population, 2, i)

# %%
population = [create_individual() for _ in range(m)]
print(population[-1])
